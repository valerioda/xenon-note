# %% [markdown]
# PMT Pulse analysis
# =======================
# A partire dal tutorial: [PMT Pulse analysis](https://straxen.readthedocs.io/en/latest/tutorials/pulse_analysis.html)

# %%
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# This just ensures some comments in dataframes below display nicely
import pandas as pd
pd.options.display.max_colwidth = 100

from scipy import stats
import straxen
from multihist import Histdd, Hist1d

# Print out exactly what versions we are using, for reference / troubleshooting:
import sys
import os.path as osp

# %%
st = straxen.contexts.xenon1t_dali()

# %% [markdown]
# Si usa un background run di XENON1T

# %%
dsets = st.select_runs(available='raw_records', include_tags='sciencerun1', run_mode='background_stable')
run_id = dsets.name.min()
print(run_id)
# Out:
# Checking data availability: 100%|██████████| 5/5 [00:51<00:00, 10.27s/it]
# 170204_1410

# %% [markdown]
# Questo run dura un'ora e non si possono caricare tutte le raw waveform data, prendiamo i primi 30 secondi:

# %%
st.data_info('raw_records')
# Out:
#      Field name        Data type  \
# 0          time            int64
# 1        length            int32
# 2            dt            int16
# 3       channel            int16
# 4  pulse_length            int32
# 5      record_i            int16
# 6      baseline            int16
# 7          data  ('<i2', (110,))
#
#                                                               Comment
# 0                                    Start time since unix epoch [ns]
# 1                                   Length of the interval in samples
# 2                                            Width of one sample [ns]
# 3                                                  Channel/PMT number
# 4  Length of pulse to which the record belongs (without zero-padding)
# 5                                        Fragment number in the pulse
# 6         Baseline determined by the digitizer (if this is supported)
# 7                                     Waveform data in raw ADC counts

# %%
rr = st.get_array(run_id, 'raw_records', seconds_range=(0, 30))
dt = rr['dt'][0]
print(rr['data'].shape)
dts = np.arange(0,rr['data'].shape[1]*dt,dt)
nn = 10
for i in range(nn):
    plt.plot(dts,rr['data'][i],label=f"{rr['channel'][i]} L={rr['pulse_length'][i]}")
plt.legend()
plt.xlabel("time (ns)", ha='right', x=1)
plt.ylabel(f"ADC", ha='right', y=1)
plt.xlim(400,700)
plt.ylim(15500,16030)
# Out:
# (2545843, 110)
# (15500.0, 16030.0)

# %%
def plotPMT(id):
    rrs = rr['data'][(rr['channel'] == id) & (rr['data'].min(1)>1.58e4) & (rr['record_i']==0)]
    nev, rsize = rrs.shape[0], rrs.shape[1]
    print('Total number of events:',nev,'length of pulses:',rsize)
    nn = nev
    if nev > 100: nn = 100
    plt.figure(1)
    for i in range(nn):
        plt.plot(dts,rrs[i],label=f"{rr['channel'][i]} L={rr['pulse_length'][i]}")
    plt.title(f'PMT n. {id}')
    plt.xlabel("time (ns)", ha='right', x=1)
    plt.ylabel(f"ADC", ha='right', y=1)
    
    bsize = 45
    bls = np.zeros([nev,bsize])
    for i in range(nev):
        for j in range(bsize):
            bls[i][j] = rrs[i][j]
    plt.figure(2)
    for i in range(nn):
        plt.plot(dts[:bsize],bls[i],label=f"{rr['channel'][i]} L={rr['pulse_length'][i]}")
    plt.title(f'PMT n. {id}')
    plt.xlabel("time (ns)", ha='right', x=1)
    plt.ylabel(f"ADC", ha='right', y=1)
        
    sampling_rate = 1/(dts[1]-dts[0])*100
    for i in range(nn):
        fft = np.fft.rfft(bls[i][:])
        abs_fft = np.abs(fft)
        if i is 0: power_spectrum = np.square(abs_fft)
        else: power_spectrum += np.square(abs_fft)
    power_spectrum /= nn
    frequency = np.linspace(0, sampling_rate/2, len(power_spectrum))
    plt.figure(3)
    plt.plot(frequency[1:], power_spectrum[1:])
    #plt.xscale("log")
    plt.yscale("log")
    plt.title(f'PMT n. {id}')
    plt.xlabel("frequency (MHz)", ha='right', x=1)
    plt.ylabel(f"power spectral density", ha='right', y=1)
    
    #import scipy.signal as signal
    ref = bls.mean(axis=0)
    offset = np.mean(ref[:])
    bl = np.zeros([nev,bsize])
    for i in range(nev):
        bl[i] = bls[i][0:bsize]-np.mean(bls[i][0:bsize])
    noise_matr =  np.matmul(bl.transpose(), bl)/nev
    #noise_matr = signal.convolve2d(noise_matr,np.identity(bsize-fsize+1), boundary='symm', mode='valid')/(bsize-fsize+1)
    
    fig, ax = plt.subplots()
    plt.title(f'PMT n. {id}')
    plt.imshow(noise_matr, cmap='viridis',origin='lower')
    plt.colorbar()

# %%
plotPMT(2)
# Out:
# Total number of events: 1926 length of pulses: 110
