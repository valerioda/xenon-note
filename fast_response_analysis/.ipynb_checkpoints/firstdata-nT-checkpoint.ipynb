# %%
print('Start import')
import socket 
import strax
import straxen
import numpy as np
import datetime
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import datetime

print(
f'''Working on {socket.getfqdn()} with the following versions 
and installation paths:
strax
\tv{strax.__version__}\t{str(strax.__path__[0])}
straxen
\tv{straxen.__version__}\t{str(straxen.__path__[0])}
''')
# Out:
# Start import
# Working on midway2-0417.rcc.local with the following versions
# and installation paths:
# strax
# 	v0.12.2	/dali/lgrandi/strax/strax/strax
# straxen
# 	v0.11.0	/dali/lgrandi/strax/straxen/straxen

# %%
st = straxen.contexts.xenonnt_online()

# %%
st.set_context_config({'check_available': ('raw_records', 'records', 'peaklets', 'peak_basics')})
st.select_runs()
# Out:
# Fetching run info from MongoDB: 100%|██████████| 221/221 [00:00<00:00, 2992.94it/s]
# Checking data availability: 100%|██████████| 4/4 [01:02<00:00, 15.71s/it]
#        name number                           mode                   start  \
# 0    009492   9492                    tpc_exttrig 2020-10-20 12:39:03.493
# 1    009491   9491        tpc_commissioning_pmtap 2020-10-19 17:53:07.651
# 2    009490   9490        tpc_commissioning_pmtap 2020-10-19 17:47:49.035
# 3    009489   9489        tpc_commissioning_pmtap 2020-10-19 17:42:15.366
# 4    009488   9488        tpc_commissioning_pmtap 2020-10-19 17:31:37.004
# ..      ...    ...                            ...                     ...
# 216  009276   9276  tpc_selftrigger_commissioning 2020-10-07 12:38:18.278
# 217  009275   9275  tpc_selftrigger_commissioning 2020-10-07 12:33:23.865
# 218  009274   9274  tpc_selftrigger_commissioning 2020-10-07 12:31:07.650
# 219  009273   9273                      tpc_noise 2020-10-07 12:29:54.507
# 220  009272   9272                      tpc_noise 2020-10-07 12:28:10.334
#
#                         end   tags        livetime  records_available  \
# 0   2020-10-20 12:49:06.471    bad 00:10:02.978000              False
# 1   2020-10-19 17:58:09.197        00:05:01.546000              False
# 2   2020-10-19 17:52:50.566        00:05:01.531000              False
# 3   2020-10-19 17:47:15.916        00:05:00.550000              False
# 4   2020-10-19 17:36:38.609    bad 00:05:01.605000              False
# ..                      ...    ...             ...                ...
# 216 2020-10-07 12:38:53.320        00:00:35.042000               True
# 217 2020-10-07 12:34:02.911  messy 00:00:39.046000               True
# 218 2020-10-07 12:31:39.688        00:00:32.038000              False
# 219 2020-10-07 12:30:44.564        00:00:50.057000              False
# 220 2020-10-07 12:28:45.375        00:00:35.041000              False
#
#      raw_records_available  peaklets_available  peak_basics_available
# 0                    False               False                  False
# 1                    False               False                  False
# 2                    False               False                  False
# 3                    False               False                  False
# 4                    False               False                  False
# ..                     ...                 ...                    ...
# 216                  False               False                  False
# 217                  False               False                  False
# 218                  False               False                  False
# 219                  False               False                  False
# 220                  False               False                  False
#
# [221 rows x 11 columns]

# %%
st.select_runs(available = 'peaklets', 
               exclude_tags = ('bad', 'messy'))
# Out:
#        name number                                      mode  \
# 20   009472   9472  tpc_selftrigger_commissioning_highthresh
# 21   009471   9471  tpc_selftrigger_commissioning_highthresh
# 22   009470   9470  tpc_selftrigger_commissioning_highthresh
# 23   009469   9469  tpc_selftrigger_commissioning_highthresh
# 26   009466   9466  tpc_selftrigger_commissioning_highthresh
# ..      ...    ...                                       ...
# 120  009372   9372    tpc_selftrigger_commissioning_veto_trg
# 121  009371   9371    tpc_selftrigger_commissioning_veto_trg
# 122  009370   9370    tpc_selftrigger_commissioning_veto_trg
# 123  009369   9369    tpc_selftrigger_commissioning_veto_trg
# 203  009289   9289             tpc_selftrigger_commissioning
#
#                       start                     end tags        livetime  \
# 20  2020-10-19 15:10:28.587 2020-10-19 15:11:30.693      00:01:02.106000
# 21  2020-10-19 15:09:05.392 2020-10-19 15:10:08.496      00:01:03.104000
# 22  2020-10-19 15:07:31.177 2020-10-19 15:08:33.281      00:01:02.104000
# 23  2020-10-19 15:06:13.990 2020-10-19 15:07:17.096      00:01:03.106000
# 26  2020-10-19 14:55:29.751 2020-10-19 14:57:08.888      00:01:39.137000
# ..                      ...                     ...  ...             ...
# 120 2020-10-15 19:57:24.034 2020-10-15 20:57:26.101      01:00:02.067000
# 121 2020-10-15 18:56:58.927 2020-10-15 19:57:00.952      01:00:02.025000
# 122 2020-10-15 17:56:39.786 2020-10-15 18:56:41.845      01:00:02.059000
# 123 2020-10-15 16:16:43.564 2020-10-15 16:26:47.223      00:10:03.659000
# 203 2020-10-07 14:23:47.045 2020-10-07 14:31:38.628      00:07:51.583000
#
#      records_available  raw_records_available  peaklets_available  \
# 20                True                  False                True
# 21                True                  False                True
# 22                True                  False                True
# 23                True                  False                True
# 26                True                  False                True
# ..                 ...                    ...                 ...
# 120               True                  False                True
# 121               True                  False                True
# 122               True                  False                True
# 123               True                   True                True
# 203               True                   True                True
#
#      peak_basics_available
# 20                   False
# 21                   False
# 22                   False
# 23                   False
# 26                   False
# ..                     ...
# 120                   True
# 121                   True
# 122                   True
# 123                   True
# 203                   True
#
# [72 rows x 11 columns]

# %%
run_id = '009375'

# %%
st.is_stored(run_id, "peak_basics")
# Out:
# True

# %%
for p in ('raw_records', 'records', 'peaklets', 'peak_basics'):
    if st.is_stored(run_id, p):
        print(f'Target: {p} \t is {st.size_mb(run_id, p):.0f} MB')
# Out:
# Target: records 	 is 444366 MB
# Target: peaklets 	 is 25704 MB
# Target: peak_basics 	 is 459 MB

# %%
peaks = st.get_array(run_id, 
                     targets = ('peak_basics'),
                     seconds_range = (0, 10), # Only first 10 seconds
                     progress_bar=False)

# %%
print(f'Loaded {peaks.nbytes/1e6:.1f} MB of peaks-data')
# Out:
# Loaded 1.3 MB of peaks-data

# %%
peaks = st.get_df(run_id, 
                     targets = ('peak_basics'),
                     seconds_range = (0, 0.01), # Only first 10 ms because I'm going to use the array from above
                     progress_bar=False).head(10)
