# %%
import sys
import os.path as osp

from copy import deepcopy
import datetime
import os
import pickle
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from multihist import Hist1d, Histdd
from tqdm.notebook import tqdm
import pandas as pd
from scipy import stats

import strax
import straxen
strax.utils.tqdm = tqdm  # use notebook-aware progress bar

# %%
import peak_s1_plots as ps1

# %%
st = straxen.contexts.xenonnt_online()

# %%
runs = st.select_runs(run_id='0085*',run_mode='*selftrigger*',available=['lone_hits','peak_basics'])

# %%
runs
# Out:
#         name number                                    mode  \
# 1367  008525   8525  xenonnt_selftrigger_commissioning_lowe
# 1368  008526   8526  xenonnt_selftrigger_commissioning_lowe
# 1369  008527   8527  xenonnt_selftrigger_commissioning_lowe
# 1370  008528   8528  xenonnt_selftrigger_commissioning_lowe
# 1373  008531   8531  xenonnt_selftrigger_commissioning_lowe
# 1374  008532   8532  xenonnt_selftrigger_commissioning_lowe
#
#                        start                     end tags        livetime  \
# 1367 2020-07-08 17:09:19.500 2020-07-08 18:09:21.830      01:00:02.330000
# 1368 2020-07-08 18:09:53.945 2020-07-08 19:09:55.270      01:00:01.325000
# 1369 2020-07-08 19:10:25.380 2020-07-08 20:10:27.790      01:00:02.410000
# 1370 2020-07-08 20:10:59.912 2020-07-08 21:11:02.421      01:00:02.509000
# 1373 2020-07-08 23:12:44.149 2020-07-09 00:12:47.749      01:00:03.600000
# 1374 2020-07-09 00:13:22.873 2020-07-09 01:13:25.307      01:00:02.434000
#
#      tags.name  peak_basics_available  raw_records_available  \
# 1367       NaN                   True                   True
# 1368       NaN                   True                  False
# 1369       NaN                   True                   True
# 1370       NaN                   True                  False
# 1373       NaN                   True                  False
# 1374       NaN                   True                  False
#
#       lone_hits_available
# 1367                 True
# 1368                 True
# 1369                 True
# 1370                 True
# 1373                 True
# 1374                 True

# %%
run_name = runs.iloc[0]['name']

# %%
peak_basics = st.get_array(run_name,'peak_basics',seconds_range=(0,30))

# %%
peak_basics = peak_basics[peak_basics['n_channels']>3]

# %%
def plot_area(peak_basics):
    p_area = Hist1d(peak_basics['area'], bins=(np.logspace(0, 4, 200)))
    p_area.plot()
    plt.xlabel("peak area (PE)", ha='right', x=1)
    plt.ylabel("events", ha='right', y=1)
    plt.xscale('log')
    plt.yscale('log')

# %%
plot_area(peak_basics)

# %%
rise_time = Hist1d(peak_basics['rise_time'], bins=(np.logspace(1, 3, 200)))
rise_time.plot()
plt.xlabel("rise time (ns)", ha='right', x=1)
plt.ylabel("events", ha='right', y=1)
plt.xscale('log')

# %%
ps1.plot_area_risetime(peak_basics)

# %%
ps1.plot_area_width(peak_basics)

# %%
ps1.plot_area_maxpmt(peak_basics)

# %%
peak_s1 = peak_basics[(peak_basics['rise_time']<150)]
ps1.plot_area_maxpmt(peak_basics)

# %%
def plot_area_top(peak_basics):
    phmax = Histdd(peak_basics['area'], peak_basics['area_fraction_top'],
                    bins=(np.logspace(0, 4, 200), np.logspace(-2, 0, 200)))
    plt.figure(figsize=(12,4))
    phmax.plot(log_scale=True, cblabel='events')
    plt.xlabel("peak area (PE)", ha='right', x=1)
    #plt.ylabel("max PMT area (PE)", ha='right', y=1)
    plt.ylabel("area fraction top", ha='right', y=1)
    plt.xscale('log')
    plt.yscale('log')

# %%
plot_area_top(peak_s1)

# %%
plot_area(peak_basics)
plot_area(peak_s1)
peak_cut = peak_s1[(peak_s1['max_pmt_area']/peak_s1['area']>0.05)]
plot_area(peak_cut)
