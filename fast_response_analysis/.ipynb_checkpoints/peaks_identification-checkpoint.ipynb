# %%
import sys
import os.path as osp

from copy import deepcopy
import datetime
import os
import pickle
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from multihist import Hist1d, Histdd
from tqdm.notebook import tqdm
import pandas as pd
from scipy import stats

import strax
import straxen
strax.utils.tqdm = tqdm  # use notebook-aware progress bar

# %%
import peaks_utility as psu

# %%
st = straxen.contexts.xenonnt_online()

# %%
runs = st.select_runs(run_id='0086*',available=['peak_basics'])
runs
# Out:
#         name number                                          mode  \
# 1442  008600   8600        xenonnt_selftrigger_commissioning_lowe
# 1443  008601   8601        xenonnt_selftrigger_commissioning_lowe
# 1444  008602   8602        xenonnt_selftrigger_commissioning_lowe
# 1445  008603   8603        xenonnt_selftrigger_commissioning_lowe
# 1446  008604   8604        xenonnt_selftrigger_commissioning_lowe
# 1448  008606   8606        xenonnt_selftrigger_commissioning_lowe
# 1453  008611   8611        xenonnt_selftrigger_commissioning_lowe
# 1454  008612   8612  xenonnt_selftrigger_commissioning_highthresh
# 1455  008613   8613  xenonnt_selftrigger_commissioning_highthresh
# 1456  008614   8614  xenonnt_selftrigger_commissioning_highthresh
# 1457  008615   8615  xenonnt_selftrigger_commissioning_highthresh
# 1458  008616   8616  xenonnt_selftrigger_commissioning_highthresh
# 1459  008617   8617  xenonnt_selftrigger_commissioning_highthresh
# 1460  008618   8618  xenonnt_selftrigger_commissioning_highthresh
# 1461  008619   8619  xenonnt_selftrigger_commissioning_highthresh
# 1462  008620   8620  xenonnt_selftrigger_commissioning_highthresh
# 1463  008621   8621  xenonnt_selftrigger_commissioning_highthresh
# 1464  008622   8622  xenonnt_selftrigger_commissioning_highthresh
# 1465  008623   8623  xenonnt_selftrigger_commissioning_highthresh
# 1466  008624   8624  xenonnt_selftrigger_commissioning_highthresh
# 1467  008625   8625  xenonnt_selftrigger_commissioning_highthresh
#
#                        start                     end   tags        livetime  \
# 1442 2020-07-12 04:09:14.764 2020-07-12 05:09:18.170        01:00:03.406000
# 1443 2020-07-12 05:10:05.326 2020-07-12 06:10:06.021        01:00:00.695000
# 1444 2020-07-12 06:10:41.150 2020-07-12 07:10:41.912        01:00:00.762000
# 1445 2020-07-12 07:11:17.047 2020-07-12 08:11:19.780        01:00:02.733000
# 1446 2020-07-12 08:11:54.917 2020-07-12 09:11:55.745  messy 01:00:00.828000
# 1448 2020-07-12 14:57:08.456 2020-07-12 14:58:38.673        00:01:30.217000
# 1453 2020-07-13 15:30:08.786 2020-07-13 16:30:09.869        01:00:01.083000
# 1454 2020-07-13 17:08:43.687 2020-07-13 17:14:57.440        00:06:13.753000
# 1455 2020-07-13 17:15:44.604 2020-07-13 18:15:47.173  messy 01:00:02.569000
# 1456 2020-07-13 18:16:16.302 2020-07-13 19:16:17.992        01:00:01.690000
# 1457 2020-07-13 19:16:51.122 2020-07-13 20:16:52.449        01:00:01.327000
# 1458 2020-07-13 20:17:21.571 2020-07-13 21:17:21.895        01:00:00.324000
# 1459 2020-07-13 21:17:52.022 2020-07-13 22:17:53.293        01:00:01.271000
# 1460 2020-07-13 22:18:22.412 2020-07-13 23:18:22.826        01:00:00.414000
# 1461 2020-07-13 23:18:55.953 2020-07-14 00:18:58.280        01:00:02.327000
# 1462 2020-07-14 00:19:30.404 2020-07-14 01:19:31.154        01:00:00.750000
# 1463 2020-07-14 01:20:00.274 2020-07-14 02:20:01.005        01:00:00.731000
# 1464 2020-07-14 02:20:30.124 2020-07-14 03:20:31.640        01:00:01.516000
# 1465 2020-07-14 03:21:03.768 2020-07-14 04:21:06.435        01:00:02.667000
# 1466 2020-07-14 04:21:35.550 2020-07-14 05:21:39.349        01:00:03.799000
# 1467 2020-07-14 05:22:11.482 2020-07-14 06:06:36.495        00:44:25.013000
#
#      tags.name  raw_records_available  peak_basics_available
# 1442       NaN                  False                   True
# 1443       NaN                  False                   True
# 1444       NaN                  False                   True
# 1445       NaN                  False                   True
# 1446       NaN                  False                   True
# 1448       NaN                  False                   True
# 1453       NaN                  False                   True
# 1454       NaN                  False                   True
# 1455       NaN                  False                   True
# 1456       NaN                  False                   True
# 1457       NaN                  False                   True
# 1458       NaN                  False                   True
# 1459       NaN                  False                   True
# 1460       NaN                  False                   True
# 1461       NaN                  False                   True
# 1462       NaN                  False                   True
# 1463       NaN                  False                   True
# 1464       NaN                  False                   True
# 1465       NaN                  False                   True
# 1466       NaN                  False                   True
# 1467       NaN                  False                   True

# %%
def peakplots(run_name):
    #run_name = runs.iloc[runnumber]['name']
    #print('Run',run_name)
    peak_basics = st.get_array(run_name,'peak_basics',seconds_range=(0,30),
                              selection_str='n_channels>3')

    # risetime
    plt.figure(1)
    psu.plot_area_risetime(peak_basics,0,5,1,5)
    #plt.axvline(x=100, ymin=0.2, ymax=0.29, linestyle="-", color = 'r', label='S1/S2 strax boundary')
    #plt.axhline(y=150, xmin=0.4, xmax=1, linestyle="-", color = 'r')
    #plt.axhline(y=60, xmin=0, xmax=0.4, linestyle="-", color = 'r')
    #plt.legend()

    # width
    plt.figure(2)
    psu.plot_area_width(peak_basics,0,5,1,5)
    psu.rectangle((50,5000),(80,200),'b')
    #ps1.rectangle((400,3500),(80,250),'blue')
    plt.text(100, 100, 'S1', fontsize=18, color='b')
    plt.text(10000, 3000, 'S2', fontsize=18, color='r')
    plt.text(7, 300, 'single electrons', fontsize=12, color='r')

    #length
    plt.figure(3)
    phle = Histdd(peak_basics['area'], peak_basics['length']*peak_basics['dt'],
                        bins=(np.logspace(0, 5, 200), np.logspace(1.7, 4.5, 150)))
    plt.figure(figsize=(12,6))
    phle.plot(log_scale=True, cblabel='events')
    plt.xlabel("peak area (PE)", ha='right', x=1)
    plt.ylabel("peak length (ns)", ha='right', y=1)
    plt.xscale('log')
    plt.yscale('log')
    # max pmt
    plt.figure(4)
    psu.plot_area_maxpmt(peak_basics,0,5,-0.5,2.3)
    
    # fraction top
    plt.figure(5)
    psu.plot_area_top(peak_basics,0,5,-2,0.1)
    
    # area
    plt.figure(6)
    plt.figure(figsize=(12,6))
    peak_s1 = peak_basics[(peak_basics['rise_time']<150)]
    psu.plot_area(peak_basics)
    psu.plot_area(peak_s1)
    #peak_cut = peak_s1[(peak_s1['max_pmt_area']/peak_s1['area']>0.04)]
    #ps1.plot_area(peak_cut)

# %%
peakplots('008600')

# %%
peakplots('008604')

# %%
peakplots('008614')

# %%
peak_basics = st.get_array('008614','peak_basics',seconds_range=(0,30),
                              selection_str='n_channels>3')
psu.plot_area_width(peak_basics,0,5.2,1,4.2)
plt.text(100, 100, 'S1', fontsize=18, color='b')
area_bounds1=(50,3000)
width_bounds1=(80,200)
area_bounds2=(2000,1e5)
width_bounds2=(300,1e4)
psu.rectangle(area_bounds1,width_bounds1,'b')
plt.text(10000, 3000, 'S2', fontsize=18, color='r')
psu.rectangle(area_bounds2,width_bounds2,'r')
plt.text(7, 300, 'single electrons', fontsize=12, color='r')
# Out:
# Text(7, 300, 'single electrons')

# %%
psu.events_vs_time(2,area_bounds2,width_bounds2)

# %%
psu.events_vs_time(1,area_bounds1,width_bounds1)

# %% [markdown]
# ## Definition of parameter F90

# %%
peaks = st.get_array('008556',['peaks','peak_basics'],seconds_range=(0,10))

# %%
psu.plotwf(peaks,1000)
# Out:
# total number of records 84536

# %%
f90(peaks,0,5,-30)

# %%
area_cut1 = (50,300)
area_cut2 = (300,1e4)
area_cut3 = (300,1e4)
f90_cut1 = (0.35,0.7)
f90_cut2 = (0.2,0.4)
f90_cut3 = (0.002,0.025)
ps1.rectangle(area_cut1,f90_cut1,'r')
ps1.rectangle(area_cut2,f90_cut2,'b')
ps1.rectangle(area_cut3,f90_cut3,'k')

# %%
peaks_cut1 = peaks[(f90<f90_cut1[1]) & (f90>f90_cut1[0]) & (peaks['area']>area_cut1[0])]
#                   & ((peaks['area']<area_cut1[1]))]
plt.figure(1)
ps1.plot_area_width(peaks_cut1,0,5.2,1,4.2)
plt.figure(2)
ps1.plot_area_maxpmt(peaks_cut1)

# %%
peaks_cut2 = peaks[(f90<f90_cut2[1]) & (f90>f90_cut2[0]) & (peaks['area']>area_cut2[0])
                    & (peaks['area']<area_cut2[1])]
plt.figure(1)
ps1.plot_area_width(peaks_cut2,0,5.2,1,4.2)
plt.figure(2)
ps1.plot_area_maxpmt(peaks_cut2)

# %%
peaks_cut3 = peaks[(f90<f90_cut3[1]) & (f90>f90_cut3[0]) & (peaks['area']>area_cut3[0])
                    & (peaks['area']<area_cut3[1])]
plt.figure(1)
ps1.plot_area_width(peaks_cut3)
plt.figure(2)
ps1.plot_area_maxpmt(peaks_cut3)

# %%
peaks_top = peak_basics[peak_basics['area_fraction_top']>0.95]
ps1.plot_area_width(peaks_top,0.5,3,1.2,4)

# %%
peaks_bot = peak_basics[peak_basics['area_fraction_top']<0.05]
ps1.plot_area_width(peaks_bot,0.5,3,1.2,4)
