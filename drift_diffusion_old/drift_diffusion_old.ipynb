# %% [markdown]
# # Drift and Diffusion in XENON1T
#
#
# La forma degli eventi S2 è determinata da 3 parametri: **drift velocity**, **diffusion constant** e **SPE waveform model**. Qui ci concentriamo sui primi 2 parametri.
#
# ## Drift Velocity
#
# Viene calcolato dalla differenza dei centri di S1 e the S2 ed è contenuto in `event_basics`.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats
import straxen
from multihist import Histdd, Hist1d

import sys
import os
import os.path as osp
from straxen import units
import pandas as pd

# %%
st = straxen.contexts.xenon1t_dali()

# %%
runs = st.select_runs(available='event_info',run_mode='background_stable')

# %%
runs
# Out:
#             name number                      start    reader.ini.name  \
# 0    170204_1410   6786  2017-02-04 14:10:08+00:00  background_stable
# 1    170204_1510   6787  2017-02-04 15:10:28+00:00  background_stable
# 2    170204_1610   6788  2017-02-04 16:10:39+00:00  background_stable
# 3    170204_1710   6789  2017-02-04 17:10:51+00:00  background_stable
# 4    170204_1810   6790  2017-02-04 18:11:01+00:00  background_stable
# 5    170204_1911   6791  2017-02-04 19:11:12+00:00  background_stable
# 6    170204_2011   6792  2017-02-04 20:11:22+00:00  background_stable
# 7    170204_2111   6793  2017-02-04 21:11:33+00:00  background_stable
# 8    170204_2211   6794  2017-02-04 22:11:44+00:00  background_stable
# 9    170204_2311   6795  2017-02-04 23:11:55+00:00  background_stable
# 10   170205_0012   6796  2017-02-05 00:12:06+00:00  background_stable
# 11   170205_0112   6797  2017-02-05 01:12:17+00:00  background_stable
# 12   170205_0212   6798  2017-02-05 02:12:27+00:00  background_stable
# 13   170205_0312   6799  2017-02-05 03:12:38+00:00  background_stable
# 14   170205_0412   6800  2017-02-05 04:12:50+00:00  background_stable
# 15   170205_0512   6801  2017-02-05 05:13:00+00:00  background_stable
# 16   170205_0613   6802  2017-02-05 06:13:12+00:00  background_stable
# 17   170205_0713   6803  2017-02-05 07:13:24+00:00  background_stable
# 18   170205_0813   6804  2017-02-05 08:13:34+00:00  background_stable
# 19   170205_0913   6805  2017-02-05 09:13:45+00:00  background_stable
# 20   170205_1013   6806  2017-02-05 10:13:56+00:00  background_stable
# 21   170205_1114   6807  2017-02-05 11:14:07+00:00  background_stable
# 22   170205_1214   6808  2017-02-05 12:14:18+00:00  background_stable
# 23   170205_1314   6809  2017-02-05 13:14:30+00:00  background_stable
# 24   170205_1414   6810  2017-02-05 14:14:39+00:00  background_stable
# 25   170205_1514   6811  2017-02-05 15:14:50+00:00  background_stable
# 26   170205_1614   6812  2017-02-05 16:15:01+00:00  background_stable
# 27   170205_1715   6813  2017-02-05 17:15:12+00:00  background_stable
# 28   170205_1815   6814  2017-02-05 18:15:23+00:00  background_stable
# 29   170205_1915   6815  2017-02-05 19:15:34+00:00  background_stable
# 30   170205_2015   6816  2017-02-05 20:15:45+00:00  background_stable
# 31   170205_2115   6817  2017-02-05 21:15:56+00:00  background_stable
# 32   170205_2216   6818  2017-02-05 22:16:07+00:00  background_stable
# 33   170205_2316   6819  2017-02-05 23:16:19+00:00  background_stable
# 34   170206_0016   6820  2017-02-06 00:16:30+00:00  background_stable
# 35   170206_0116   6821  2017-02-06 01:16:41+00:00  background_stable
# 36   170206_0216   6822  2017-02-06 02:17:03+00:00  background_stable
# 37   170206_0317   6823  2017-02-06 03:17:14+00:00  background_stable
# 38   170206_0417   6824  2017-02-06 04:17:26+00:00  background_stable
# 39   170206_0517   6825  2017-02-06 05:17:39+00:00  background_stable
# 40   170206_0617   6826  2017-02-06 06:17:50+00:00  background_stable
# 41   170206_0717   6827  2017-02-06 07:18:00+00:00  background_stable
# 140  170621_0617  10635  2017-06-21 06:17:24+00:00  background_stable
#
#     trigger.events_built                        end  \
# 0                  19574  2017-02-04 15:10:13+00:00
# 1                  19634  2017-02-04 16:10:32+00:00
# 2                  19400  2017-02-04 17:10:43+00:00
# 3                  19415  2017-02-04 18:10:54+00:00
# 4                  19671  2017-02-04 19:11:05+00:00
# 5                  19577  2017-02-04 20:11:15+00:00
# 6                  19432  2017-02-04 21:11:26+00:00
# 7                  19577  2017-02-04 22:11:37+00:00
# 8                  19486  2017-02-04 23:11:48+00:00
# 9                  19129  2017-02-05 00:11:59+00:00
# 10                 19448  2017-02-05 01:12:10+00:00
# 11                 19352  2017-02-05 02:12:20+00:00
# 12                 19094  2017-02-05 03:12:31+00:00
# 13                 19427  2017-02-05 04:12:42+00:00
# 14                 19573  2017-02-05 05:12:53+00:00
# 15                 19461  2017-02-05 06:13:04+00:00
# 16                 19452  2017-02-05 07:13:15+00:00
# 17                 19437  2017-02-05 08:13:27+00:00
# 18                 19226  2017-02-05 09:13:38+00:00
# 19                 19449  2017-02-05 10:13:49+00:00
# 20                 19573  2017-02-05 11:14:00+00:00
# 21                 19176  2017-02-05 12:14:11+00:00
# 22                 19592  2017-02-05 13:14:22+00:00
# 23                 19411  2017-02-05 14:14:32+00:00
# 24                 19607  2017-02-05 15:14:43+00:00
# 25                 19571  2017-02-05 16:14:54+00:00
# 26                 19357  2017-02-05 17:15:05+00:00
# 27                 19429  2017-02-05 18:15:16+00:00
# 28                 19581  2017-02-05 19:15:27+00:00
# 29                 19511  2017-02-05 20:15:38+00:00
# 30                 19182  2017-02-05 21:15:49+00:00
# 31                 19289  2017-02-05 22:16:00+00:00
# 32                 19305  2017-02-05 23:16:12+00:00
# 33                 19154  2017-02-06 00:16:23+00:00
# 34                 19411  2017-02-06 01:16:34+00:00
# 35                 19732  2017-02-06 02:16:44+00:00
# 36                 19564  2017-02-06 03:17:07+00:00
# 37                 19450  2017-02-06 04:17:18+00:00
# 38                 19364  2017-02-06 05:17:29+00:00
# 39                 19443  2017-02-06 06:17:42+00:00
# 40                 19617  2017-02-06 07:17:53+00:00
# 41                 19569  2017-02-06 08:18:04+00:00
# 140                19084  2017-06-21 07:17:25+00:00
#
#                                             tags               mode livetime  \
# 0    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:05
# 1    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 2    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 3    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 4    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 5    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 6    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 7    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 8    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 9    blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 10   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 11   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 12   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 13   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 14   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 15   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 16   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 17   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 18   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 19   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 20   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 21   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 22   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 23   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:02
# 24   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 25   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 26   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 27   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 28   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 29   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 30   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 31   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 32   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:05
# 33   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 34   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 35   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 36   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 37   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 38   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 39   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 40   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:03
# 41   blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:04
# 140  blinded,_sciencerun1_candidate,_sciencerun1  background_stable 01:00:01
#
#     tags.name  event_info_available  raw_records_available  \
# 0         NaN                  True                   True
# 1         NaN                  True                   True
# 2         NaN                  True                   True
# 3         NaN                  True                   True
# 4         NaN                  True                   True
# 5         NaN                  True                   True
# 6         NaN                  True                   True
# 7         NaN                  True                   True
# 8         NaN                  True                   True
# 9         NaN                  True                   True
# 10        NaN                  True                   True
# 11        NaN                  True                   True
# 12        NaN                  True                   True
# 13        NaN                  True                   True
# 14        NaN                  True                   True
# 15        NaN                  True                   True
# 16        NaN                  True                   True
# 17        NaN                  True                   True
# 18        NaN                  True                   True
# 19        NaN                  True                   True
# 20        NaN                  True                   True
# 21        NaN                  True                   True
# 22        NaN                  True                   True
# 23        NaN                  True                   True
# 24        NaN                  True                   True
# 25        NaN                  True                   True
# 26        NaN                  True                   True
# 27        NaN                  True                   True
# 28        NaN                  True                   True
# 29        NaN                  True                   True
# 30        NaN                  True                   True
# 31        NaN                  True                   True
# 32        NaN                  True                   True
# 33        NaN                  True                   True
# 34        NaN                  True                   True
# 35        NaN                  True                   True
# 36        NaN                  True                   True
# 37        NaN                  True                   True
# 38        NaN                  True                   True
# 39        NaN                  True                   True
# 40        NaN                  True                   True
# 41        NaN                  True                   True
# 140       NaN                  True                   True
#
#      peaklets_available  records_available  events_available
# 0                  True               True              True
# 1                  True               True              True
# 2                  True               True              True
# 3                  True               True              True
# 4                  True               True              True
# 5                  True               True              True
# 6                  True               True              True
# 7                  True               True              True
# 8                  True               True              True
# 9                  True               True              True
# 10                 True               True              True
# 11                 True               True              True
# 12                 True               True              True
# 13                 True               True              True
# 14                 True               True              True
# 15                 True               True              True
# 16                 True               True              True
# 17                 True               True              True
# 18                 True               True              True
# 19                 True               True              True
# 20                 True               True              True
# 21                 True               True              True
# 22                 True               True              True
# 23                 True               True              True
# 24                 True               True              True
# 25                 True               True              True
# 26                 True               True              True
# 27                 True               True              True
# 28                 True               True              True
# 29                 True               True              True
# 30                 True               True              True
# 31                 True               True              True
# 32                 True               True              True
# 33                 True               True              True
# 34                 True               True              True
# 35                 True               True              True
# 36                 True               True              True
# 37                 True               True              True
# 38                 True               True              True
# 39                 True               True              True
# 40                 True               True              True
# 41                 True               True              True
# 140                True               True              True

# %%
print('Number of runs:', len(runs))
# Out:
# Number of runs: 43

# %% [markdown]
# Il codice seguente fa un loop su più run e riempie i vettori con i drift times (in `event_basics`) ed il rapporto tra le aree dopo la correzione (in `corrected_areas`)

# %%
def select_data_from_runs( runs, nrun ,firstrun=0):
    s2 = []
    cs1 = []
    cs2 = []
    s2_50 = []
    s2_aft = []
    drift_times = []
    data = pd.DataFrame(columns=['cs1','cs2','s2','s2_a50','s2_aft','drift_times'])
    print(data)
    for i in range(nrun):
        run_info = runs.iloc[i+firstrun]
        events = st.get_array(run_info['name'],'event_basics')
        c_areas = st.get_array(run_info['name'],'corrected_areas')
        for k in range(len(events)):
            s2.append(events['s2_area'][k]) 
            s2_50.append(events['s2_range_50p_area'][k])
            s2_aft.append(events['s2_area_fraction_top'][k])
            drift_times.append(events['drift_time'][k] / units.us)
            cs1.append(c_areas['cs1'][k])
            cs2.append(c_areas['cs2'][k])
    data['cs1'] = cs1
    data['cs2'] = cs2
    data['s2'] = s2
    data['s2_50'] = s2_50
    data['s2_aft'] = s2_aft
    data['drift_times'] = drift_times
    frun = runs.iloc[firstrun]['name']
    lrun = runs.iloc[nrun+firstrun]['name']
    print('First run:',frun,'Last run:',lrun)
    print('Total number of events:',len(s2))
    fname = f'data_{frun}-{lrun}.h5'
    data.to_hdf(fname, key='data', mode='w')
    print('Data saved in file',fname)
    #return s2, cs1, cs2, s2_50, s2_aft, drift_times
    return data

# %%
#s2, cs1, cs2, s2_50, s2_aft, drift_times = select_events(runs,20)
select_events( runs, 10, 22 )
# Out:
# Empty DataFrame
# Columns: [cs1, cs2, s2, s2_a50, s2_aft, drift_times]
# Index: []
# First run: 170205_1214 Last run: 170205_2216
# Total number of events: 194066
# Data saved in file data_170205_1214-170205_2216.h5
# /dali/lgrandi/strax/miniconda3/envs/strax/lib/python3.7/site-packages/pandas/core/generic.py:2505: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->floating,key->block1_values] [items->Index(['s2_a50'], dtype='object')]
#
#   encoding=encoding,
#                 cs1           cs2             s2 s2_a50    s2_aft  \
# 0       7129.023926  1.185022e+06  374793.625000    NaN  0.620362
# 1          0.000000  8.311277e+05  743122.187500    NaN  0.418117
# 2       1992.459351  2.005234e+05  217563.375000    NaN  0.602873
# 3       1581.798096  1.557970e+05  140987.234375    NaN  0.633558
# 4       2956.309326  2.826968e+05   92366.273438    NaN  0.650265
# ...             ...           ...            ...    ...       ...
# 194061   904.733398  1.626310e+05   37319.800781    NaN  0.683848
# 194062  2939.903320  3.612302e+05  260414.421875    NaN  0.669368
# 194063  6985.961426  7.016096e+05  533645.937500    NaN  0.502496
# 194064  6414.928711  9.410731e+05  847671.250000    NaN  0.513566
# 194065  4982.341309  4.818303e+05  218083.765625    NaN  0.656458
#
#         drift_times        s2_50
# 0           492.789  1799.278564
# 1             0.000   271.231445
# 2             9.892   341.289795
# 3            34.199   519.860229
# 4           534.925  1901.681152
# ...             ...          ...
# 194061      697.808  2121.556152
# 194062      160.915  1017.530273
# 194063       40.716   624.914551
# 194064       16.928   617.708252
# 194065      397.198  1589.654297
#
# [194066 rows x 7 columns]

# %%
local_dir = os.getcwd()
count = 0
fnames = []
for p, d, files in os.walk(local_dir):
    d.sort()
    for f in sorted(files):
        if f.endswith(".h5"):
            fnames.append(f)
            count+=1
print(fnames)                  
data = pd.read_hdf(fnames[0], 'data')
# Out:
# ['data_170204_1410-170205_0012.h5', 'data_170205_0012-170205_1013.h5', 'data_170205_1013-170205_2015.h5', 'data_170205_2015-170206_0617.h5']

# %%
drift_hist, drift_bin = np.histogram(data['drift_times'],bins=800, range=(400,800))
plt.plot(drift_bin[1:],drift_hist)
plt.xlabel('drift time ($\mu$s)', ha='right', x=1)
plt.ylabel('events', ha='right', y=1)
drift_max = drift_bin[int(drift_hist.argmax())]
plt.axvline(drift_max, c='red', linestyle=":",label=f'cathode drop-off: {drift_max:.1f} $\mu s$')
plt.legend()
plt.savefig("drift-time.png")

# %% [markdown]
# Il massimo nello spettro del **drift time**: il rate di eventi aumenta scendendo nella TPC, dato che la schermo di xenon (da gamma provenienti da materiali sotto la TPC) si riduce sempre di più; fino a diminuire improvvisamente dato che S2 non possoono essere collezionati da sotto il catodo.

# %% [markdown]
# ### Ratio Between S2 and S1 corrected areas

# %%
import math
area_ratio = np.zeros(len(data))
area_ratio10 = np.zeros(len(data))
bool = (data['cs1']>0) & (data['cs2']>0) & (np.invert(np.isnan(data['cs1'])))
for i in range(len(data)):
    if bool[i]:
        area_ratio[i] = data['cs2'][i]/data['cs1'][i]
        area_ratio10[i] = math.log10(data['cs2'][i]/data['cs1'][i])
#if bool: area_ratio[:] = cs2[:]/cs1[:]
area_hist, area_bin = np.histogram(area_ratio,bins=800, range=(0,10000))
plt.plot(area_bin[1:],area_hist)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('cS2/cS1', ha='right', x=1)
plt.ylabel('events', ha='right', y=1)
# Out:
# Text(0, 1, 'events')

# %%
#plt.scatter(drift_times,area_ratio10, marker='.', s=20)
#plt.xlim(400,800)
#plt.ylim(-2,4)
d_vs_a = Histdd(data['drift_times'], area_ratio10,
            bins=(np.linspace(400, 800, 200), np.linspace(-2, 4, 100)))
#plt.figure(figsize=(20,10))
d_vs_a.plot(log_scale=True, cblabel='events')
plt.xlabel('drift time ($\mu$s)', ha='right', x=1)
plt.ylabel('log10(cS2/cS1)', ha='right', y=1)
plt.axvline(drift_max, c='red', linestyle=":",label=f'cathode drop-off {drift_max:.1f} $\mu s$')
plt.legend()
plt.savefig("dt-area_high.png")

# %% [markdown]
# * **low S2/S1 events**, sono prodotti da electron clouds che si trovano nella regione di inversione del campo al catodo, parte della carica va verso **bottom screen** e non risale all'anodo
# * **large S2s** sono prodotti in regione con alto campo vicino i fili del catodo; questo sopprime l'effetto di ricombinazione delle coppie, aumentando quindi S2
#
# **Campi Elettrici nella TPC**
# 1. campo elettrico tra il catodo (negativo, in basso) e il gate, serve per muovere gli elettroni verso il gas
# 2. campo elettrico tra il gate e l'anodo (positivo, in alto), serve per estrarre gli elettroni che eccitano e/o ionizzano gli atomi del gas e producono S2

# %% [markdown]
# ### Drift time of gate events
#
# Gli eventi creati al gate non sono visibili nello spettro del drift time, bisogna guardare a tempi più bassi se guardiamo però la regione a bassi. Eventi possono essere generati anche nel sottile strato tra il gate e l'anodo.

# %%
mh = Histdd(data['drift_times'], area_ratio10,
            bins=(np.linspace(0, 7, 70), np.linspace(1, 3.5, 100)),
            axis_names=['drift_time', 'area_ratio'])
mh.plot(log_scale=True, cblabel='Events / bin')
plt.xlabel("drift time ($\mu$s)", ha='right', x=1)
plt.ylabel("log10(cS2/cS1)", ha='right', y=1)

median = mh.percentile(50, axis='area_ratio')
#n_per_slice = mh.sum(axis='logcsratio')
#sigma = (mh.percentile(stats.norm.cdf(1)*100, axis='logcsratio') - 
#         mh.percentile(stats.norm.cdf(-1)*100, axis='logcsratio'))/2
#plt.errorbar(median.bin_centers, median.histogram,
#             yerr=sigma/np.sqrt(n_per_slice.histogram), c='red')
median.plot(color='red',label='median')
plt.legend()
plt.savefig("dt-area_low.png")

# %% [markdown]
# A tempi sotto i 3 $\mu$s il rapporto cS1/cS2 sale, questo è dovuto al fatto che il campo elettrico cresce passando il gate sopprimento l'effetto di ricombinazione e quindi aumentando S2 a discapito di S1.
#
# La posizione orientativo del gate è dove c'è il rapido cambio intorno a $1.5~\mu$s.

# %% [markdown]
# ### Drift Velocity

# %%
cathode_dt = drift_max * units.us
dt_offset = 1.5 * units.us
tpc_length = 97 * units.cm #lunghezza approssimata della TPC di XENON1T
drift_velocity = tpc_length / (cathode_dt - dt_offset)
print("Drift velocity determined at %0.3f km/sec" % (drift_velocity/(units.km/units.s)))
# Out:
# Drift velocity determined at 1.338 km/sec

# %% [markdown]
# ## Diffusion Constant

# %% [markdown]
# ### Richiamo di teoria
#
# The diffusion constant $D$ describes the diffusive broadening of electron clouds, and eventually the S2 signals, with increasing drift time.
#
# Non ci sono molti lavori a riguardo, si prende come riferimento quello di [Sorensen](https://arxiv.org/abs/1102.2865) che definisce la devisione standard del segnale S2 (per un infinitely thin gas gap):
#
# \begin{equation}
# \sigma = \frac{\sqrt{2 D t}}{v}
# \end{equation}
# il numeratore è la larghezza longitudinale dell'electron cloud con $t$ the drift time, $v$ è la drift velocity.
#
# Per $t$ lunghi ($>30\mu$s per Sorensen), la diffusione rende la forma di S2 ancora una gaussiana approssimata, si usa una versione modificata dell'equazionee:
#
# \begin{equation}
# \sigma = \sqrt{\frac{2 D t}{v^2} + {\sigma_0}^2}
# \end{equation}
# dove $\sigma_0$ è una costante da settare; se la risposta al SPE fosse una gaussiana perfetta, $\sigma_0$ sarebbe la larghezza di very shallow S2s.
#
# Viene utilizzata l'area al 50% area $r_{50}$ per misurare la larghezza di S2, in modo da evitare la coda. Facendo l'aprossimazione di gaussiana $r_{50} \approx 1.349 \sigma$ si può scrivere:
#
# \begin{equation}
# r_{50} = \sqrt{\frac{3.6395 D t}{v^2} + {w_0}^2}
# \end{equation}
#
# ### S2 width vs energy
# la larghezza dipende dall'energia per 2 effetti:
#
# * i segnali S2 hanno una certa distribuzione per la width dovuta al numero finito di elettroni, a **bassa statistica** gli stimatori della larghezza non sono molto corretti;
# * al contrario, per gli S2 ad **alte energie** c'è la saturation dell'ADC, che taglia parte dell'area e questo provoca un aumento della larghezza (con S2 ~ 30k PE) (vedere meglio questa cosa)

# %%
s2_top2 = Histdd(data['s2'], data['s2_aft'],bins=(np.logspace(2, 6, 50), np.linspace(0.4, 0.8, 50)))
s2_top2.plot(log_scale=True)
s2_bounds = (3e3, 2e4)
aft_bounds = (0.55, 0.67)
plt.gca().add_patch(matplotlib.patches.Rectangle(
        (s2_bounds[0], aft_bounds[0]), s2_bounds[1] - s2_bounds[0], 
    aft_bounds[1] - aft_bounds[0],
    edgecolor='red',facecolor='none'))

plt.xscale('log')
plt.xlabel('S2 (PE)', ha='right', x=1)
plt.ylabel('S2 area fraction top', ha='right', y=1)
plt.tight_layout()

# %% [markdown]
# Per gli effetti descritti sopra si guarda **S2** che è sensibile alla saturazione (e non cS2) vs **S2 area fraction top (AFT)**.
#
# Jelle utilizza i tagli mostrati nel grafico: s2[10k:20k] e AFT[0.55:0.7].
#
# AFT diminuisce ad alte energia: questo anche è dovuto alla saturazione nel top array.

# %%
width_hist = Histdd(data['drift_times'], data['s2_50'],
            bins=(np.linspace(0, 800, 800), np.linspace(0, 3e3, 200)));
width_hist.plot(log_scale=True, cblabel='events')
plt.xlabel('drift time ($\mu$s)')
plt.ylabel('S2 width range 50% area (ns)')
# Out:
# Text(0, 0.5, 'S2 width range 50% area (ns)')

# %%
data_cut = data[(data['s2']>s2_bounds[0]) & (data['s2']<s2_bounds[1]) &
            (data['s2_aft']>aft_bounds[0]) & (data['s2_aft']<aft_bounds[1])]
width_hist_cut = Histdd(data_cut['drift_times'], data_cut['s2_50'],
            bins=(np.linspace(0, 800, 800), np.linspace(0, 3e3, 200)));
width_hist_cut.plot(log_scale=True, cblabel='events')
plt.xlabel('drift time ($\mu$s)')
plt.ylabel('S2 width range 50% area (ns)')
# Out:
# Text(0, 0.5, 'S2 width range 50% area (ns)')

# %% [markdown]
# Il taglio su S2 rimuove:
# * eventi di alta energia dove si ha la saturazione dell'ADC (e questo allarga artificialmente S2-width)
# * eventi di bassa energia dove non vale l'equazione della diffusione per la statistica bassa
#
# Il taglio sulla frazione vista dai PMT in alto (S2_AFT) rimuove:
# * eventi che avvengono nelle vicinanze del top array (o nel gas) che hanno un `drift time` breve e una larghezza maggiore

# %% [markdown]
# ### Fit to determine the Diffusion Constant
# Per fare il fit vengono usati soltanto tempi tra 50 e 350 us:
# * in basso per garantire che S2 abbia una distribuzione guassiana
# * in alto per rimuovere eventi ad alta statistica che producono eventi anomali

# %%
from scipy.optimize import curve_fit
from tqdm import tqdm
import emcee

D_guess = 30 * units.cm**2 / units.s
w0_guess = 300 * units.ns
wsigma_guess = 30 * units.ns
sigma_to_r50p = stats.norm.ppf(0.75) - stats.norm.ppf(0.25)
def diffusion_model(t, D, vd, w0):
    return np.sqrt(2 * sigma_to_r50p**2 * D * t / vd**2 + w0**2)

def fit_diffusion(drift_times, s2_50, vd, outlier_cap=-15):
    def loglikelihood(params):
        D, w0, wsigma = params

        # Range constraint / uniform prior. Probably not necessary anymore.
        if not (5 < D < 50 and (100  < w0/units.ns < 500) and (10 < wsigma/units.ns < 100)):
            return -float('inf')

        D *= (units.cm**2 / units.s)

        y = s2_50
        model = diffusion_model(drift_times, D, vd, w0)

        # Gaussian loglikelihood, with outlier contribution capped
        inv_sigma2 = 1.0/wsigma**2
        result = -0.5 * ((y-model)**2*inv_sigma2 - np.log(inv_sigma2))
        result = np.clip(result, outlier_cap, 1)
        return np.sum(result)

    guess = np.array([D_guess/(units.cm**2 / units.s), w0_guess, wsigma_guess])
    n_walkers = 50
    n_steps = 250
    n_dim = len(guess)

    # Hack to show a progress bar during the computation
    def lnprob(x):
        lnprob.t.update(1)
        return loglikelihood(x)
    lnprob.t = tqdm(desc='Computing likelihoods', total=n_walkers * n_steps)

    # Run the MCMC sampler
    p0 = np.array([np.random.uniform(0.9, 1.1, size=n_dim) for i in range(n_walkers)]) * guess
    sampler = emcee.EnsembleSampler(n_walkers, n_dim, lnprob)
    samples = sampler.run_mcmc(p0, n_steps)

    # Remove first 50 samples for each walker (burn-in)
    samples = sampler.chain.ravel()
    samples = sampler.chain[:, 50:, :].reshape((-1, n_dim))
    return samples

# %%
D_fit_range_us = (10, 300)
data_fit = data_cut[(data_cut['drift_times']>D_fit_range_us[0]) &
                   (data_cut['drift_times']<D_fit_range_us[1])]
samples = fit_diffusion(data_fit['drift_times'], data_fit['s2_50'], vd=drift_velocity)
# Out:
# Computing likelihoods:   0%|          | 0/12500 [00:00<?, ?it/s]
# Computing likelihoods:   0%|          | 26/12500 [00:00<00:49, 253.28it/s]
# Computing likelihoods:   0%|          | 57/12500 [00:00<00:46, 267.68it/s]
# Computing likelihoods:   1%|          | 90/12500 [00:00<00:43, 282.51it/s]
# Computing likelihoods:   1%|          | 124/12500 [00:00<00:41, 295.25it/s]
# Computing likelihoods:   1%|          | 156/12500 [00:00<00:40, 301.75it/s]
# Computing likelihoods:   2%|▏         | 188/12500 [00:00<00:40, 305.75it/s]
# Computing likelihoods:   2%|▏         | 219/12500 [00:00<00:40, 306.77it/s]
# Computing likelihoods:   2%|▏         | 254/12500 [00:00<00:38, 317.27it/s]
# Computing likelihoods:   2%|▏         | 286/12500 [00:00<00:38, 317.40it/s]
# Computing likelihoods:   3%|▎         | 318/12500 [00:01<00:38, 317.12it/s]
# Computing likelihoods:   3%|▎         | 350/12500 [00:01<00:39, 310.63it/s]
# Computing likelihoods:   3%|▎         | 381/12500 [00:01<00:40, 296.98it/s]
# Computing likelihoods:   3%|▎         | 411/12500 [00:01<00:41, 294.10it/s]
# Computing likelihoods:   4%|▎         | 441/12500 [00:01<00:42, 285.09it/s]
# Computing likelihoods:   4%|▍         | 470/12500 [00:01<00:45, 265.48it/s]
# Computing likelihoods:   4%|▍         | 497/12500 [00:01<00:45, 261.48it/s]
# Computing likelihoods:   4%|▍         | 531/12500 [00:01<00:42, 279.21it/s]
# Computing likelihoods:   5%|▍         | 564/12500 [00:01<00:40, 291.53it/s]
# Computing likelihoods:   5%|▍         | 597/12500 [00:01<00:39, 300.21it/s]
# Computing likelihoods:   5%|▌         | 631/12500 [00:02<00:38, 310.25it/s]
# Computing likelihoods:   5%|▌         | 663/12500 [00:02<00:38, 308.27it/s]
# Computing likelihoods:   6%|▌         | 695/12500 [00:02<00:38, 307.48it/s]
# Computing likelihoods:   6%|▌         | 739/12500 [00:02<00:34, 337.12it/s]
# Computing likelihoods:   6%|▌         | 774/12500 [00:02<00:34, 340.72it/s]
# Computing likelihoods:   6%|▋         | 809/12500 [00:02<00:34, 339.63it/s]
# Computing likelihoods:   7%|▋         | 844/12500 [00:02<00:36, 321.82it/s]
# Computing likelihoods:   7%|▋         | 878/12500 [00:02<00:35, 326.91it/s]
# Computing likelihoods:   7%|▋         | 912/12500 [00:02<00:35, 326.23it/s]
# Computing likelihoods:   8%|▊         | 949/12500 [00:03<00:34, 337.47it/s]
# Computing likelihoods:   8%|▊         | 984/12500 [00:03<00:34, 331.66it/s]
# Computing likelihoods:   8%|▊         | 1020/12500 [00:03<00:33, 339.26it/s]
# Computing likelihoods:   8%|▊         | 1055/12500 [00:03<00:33, 338.93it/s]
# Computing likelihoods:   9%|▊         | 1090/12500 [00:03<00:34, 334.96it/s]
# Computing likelihoods:   9%|▉         | 1124/12500 [00:03<00:34, 332.18it/s]
# Computing likelihoods:   9%|▉         | 1158/12500 [00:03<00:34, 329.43it/s]
# Computing likelihoods:  10%|▉         | 1192/12500 [00:03<00:35, 318.17it/s]
# Computing likelihoods:  10%|▉         | 1227/12500 [00:03<00:34, 326.43it/s]
# Computing likelihoods:  10%|█         | 1263/12500 [00:03<00:33, 335.80it/s]
# Computing likelihoods:  10%|█         | 1297/12500 [00:04<00:35, 315.96it/s]
# Computing likelihoods:  11%|█         | 1329/12500 [00:04<00:35, 315.10it/s]
# Computing likelihoods:  11%|█         | 1361/12500 [00:04<00:36, 301.19it/s]
# Computing likelihoods:  11%|█         | 1392/12500 [00:04<00:37, 299.44it/s]
# Computing likelihoods:  11%|█▏        | 1426/12500 [00:04<00:35, 308.69it/s]
# Computing likelihoods:  12%|█▏        | 1458/12500 [00:04<00:35, 307.91it/s]
# Computing likelihoods:  12%|█▏        | 1491/12500 [00:04<00:35, 313.60it/s]
# Computing likelihoods:  12%|█▏        | 1523/12500 [00:04<00:34, 313.82it/s]
# Computing likelihoods:  13%|█▎        | 1568/12500 [00:04<00:31, 345.01it/s]
# Computing likelihoods:  13%|█▎        | 1610/12500 [00:05<00:30, 361.79it/s]
# Computing likelihoods:  13%|█▎        | 1652/12500 [00:05<00:28, 376.19it/s]
# Computing likelihoods:  14%|█▎        | 1698/12500 [00:05<00:27, 397.42it/s]
# Computing likelihoods:  14%|█▍        | 1739/12500 [00:05<00:27, 394.88it/s]
# Computing likelihoods:  14%|█▍        | 1780/12500 [00:05<00:28, 381.38it/s]
# Computing likelihoods:  15%|█▍        | 1819/12500 [00:05<00:28, 376.69it/s]
# Computing likelihoods:  15%|█▍        | 1858/12500 [00:05<00:31, 334.52it/s]
# Computing likelihoods:  15%|█▌        | 1893/12500 [00:05<00:35, 301.34it/s]
# Computing likelihoods:  15%|█▌        | 1931/12500 [00:05<00:33, 319.80it/s]
# Computing likelihoods:  16%|█▌        | 1968/12500 [00:06<00:31, 331.10it/s]
# Computing likelihoods:  16%|█▌        | 2003/12500 [00:06<00:31, 329.25it/s]
# Computing likelihoods:  16%|█▋        | 2037/12500 [00:06<00:35, 292.30it/s]
# Computing likelihoods:  17%|█▋        | 2068/12500 [00:06<00:38, 271.92it/s]
# Computing likelihoods:  17%|█▋        | 2097/12500 [00:06<00:43, 236.99it/s]
# Computing likelihoods:  17%|█▋        | 2135/12500 [00:06<00:38, 266.45it/s]
# Computing likelihoods:  17%|█▋        | 2168/12500 [00:06<00:36, 280.97it/s]
# Computing likelihoods:  18%|█▊        | 2205/12500 [00:06<00:34, 302.26it/s]
# Computing likelihoods:  18%|█▊        | 2246/12500 [00:07<00:31, 327.29it/s]
# Computing likelihoods:  18%|█▊        | 2291/12500 [00:07<00:28, 354.62it/s]
# Computing likelihoods:  19%|█▊        | 2331/12500 [00:07<00:27, 366.59it/s]
# Computing likelihoods:  19%|█▉        | 2371/12500 [00:07<00:27, 372.72it/s]
# Computing likelihoods:  19%|█▉        | 2423/12500 [00:07<00:24, 405.54it/s]
# Computing likelihoods:  20%|█▉        | 2468/12500 [00:07<00:24, 417.77it/s]
# Computing likelihoods:  20%|██        | 2511/12500 [00:07<00:24, 401.32it/s]
# Computing likelihoods:  20%|██        | 2553/12500 [00:07<00:25, 394.91it/s]
# Computing likelihoods:  21%|██        | 2594/12500 [00:07<00:25, 391.34it/s]
# Computing likelihoods:  21%|██        | 2636/12500 [00:07<00:24, 396.63it/s]
# Computing likelihoods:  21%|██▏       | 2684/12500 [00:08<00:23, 415.81it/s]
# Computing likelihoods:  22%|██▏       | 2727/12500 [00:08<00:24, 405.11it/s]
# Computing likelihoods:  22%|██▏       | 2775/12500 [00:08<00:22, 423.16it/s]
# Computing likelihoods:  23%|██▎       | 2818/12500 [00:08<00:23, 409.86it/s]
# Computing likelihoods:  23%|██▎       | 2860/12500 [00:08<00:24, 388.63it/s]
# Computing likelihoods:  23%|██▎       | 2908/12500 [00:08<00:23, 411.85it/s]
# Computing likelihoods:  24%|██▎       | 2950/12500 [00:08<00:23, 402.31it/s]
# Computing likelihoods:  24%|██▍       | 2992/12500 [00:08<00:23, 406.77it/s]
# Computing likelihoods:  24%|██▍       | 3034/12500 [00:08<00:23, 402.46it/s]
# Computing likelihoods:  25%|██▍       | 3075/12500 [00:09<00:23, 397.21it/s]
# Computing likelihoods:  25%|██▍       | 3121/12500 [00:09<00:22, 412.65it/s]
# Computing likelihoods:  25%|██▌       | 3163/12500 [00:09<00:22, 408.15it/s]
# Computing likelihoods:  26%|██▌       | 3205/12500 [00:09<00:23, 400.24it/s]
# Computing likelihoods:  26%|██▌       | 3246/12500 [00:09<00:24, 378.63it/s]
# Computing likelihoods:  26%|██▋       | 3285/12500 [00:09<00:25, 356.14it/s]
# Computing likelihoods:  27%|██▋       | 3322/12500 [00:09<00:26, 352.31it/s]
# Computing likelihoods:  27%|██▋       | 3359/12500 [00:09<00:25, 354.67it/s]
# Computing likelihoods:  27%|██▋       | 3395/12500 [00:09<00:26, 344.00it/s]
# Computing likelihoods:  27%|██▋       | 3432/12500 [00:10<00:25, 349.40it/s]
# Computing likelihoods:  28%|██▊       | 3468/12500 [00:10<00:25, 348.45it/s]
# Computing likelihoods:  28%|██▊       | 3505/12500 [00:10<00:25, 352.01it/s]
# Computing likelihoods:  28%|██▊       | 3541/12500 [00:10<00:26, 343.46it/s]
# Computing likelihoods:  29%|██▊       | 3576/12500 [00:10<00:26, 336.96it/s]
# Computing likelihoods:  29%|██▉       | 3620/12500 [00:10<00:24, 361.20it/s]
# Computing likelihoods:  29%|██▉       | 3659/12500 [00:10<00:23, 368.51it/s]
# Computing likelihoods:  30%|██▉       | 3703/12500 [00:10<00:22, 386.33it/s]
# Computing likelihoods:  30%|██▉       | 3744/12500 [00:10<00:22, 389.83it/s]
# Computing likelihoods:  30%|███       | 3784/12500 [00:10<00:22, 390.38it/s]
# Computing likelihoods:  31%|███       | 3827/12500 [00:11<00:21, 401.20it/s]
# Computing likelihoods:  31%|███       | 3868/12500 [00:11<00:22, 387.76it/s]
# Computing likelihoods:  31%|███▏      | 3915/12500 [00:11<00:21, 407.93it/s]
# Computing likelihoods:  32%|███▏      | 3967/12500 [00:11<00:19, 432.97it/s]
# Computing likelihoods:  32%|███▏      | 4012/12500 [00:11<00:19, 430.08it/s]
# Computing likelihoods:  32%|███▏      | 4056/12500 [00:11<00:19, 431.85it/s]
# Computing likelihoods:  33%|███▎      | 4107/12500 [00:11<00:18, 451.53it/s]
# Computing likelihoods:  33%|███▎      | 4153/12500 [00:11<00:18, 452.72it/s]
# Computing likelihoods:  34%|███▎      | 4203/12500 [00:11<00:17, 463.29it/s]
# Computing likelihoods:  34%|███▍      | 4259/12500 [00:11<00:16, 487.49it/s]
# Computing likelihoods:  34%|███▍      | 4309/12500 [00:12<00:17, 475.24it/s]
# Computing likelihoods:  35%|███▍      | 4357/12500 [00:12<00:17, 458.18it/s]
# Computing likelihoods:  35%|███▌      | 4404/12500 [00:12<00:17, 458.20it/s]
# Computing likelihoods:  36%|███▌      | 4451/12500 [00:12<00:17, 455.24it/s]
# Computing likelihoods:  36%|███▌      | 4500/12500 [00:12<00:17, 464.55it/s]
# Computing likelihoods:  36%|███▋      | 4547/12500 [00:12<00:17, 464.21it/s]
# Computing likelihoods:  37%|███▋      | 4594/12500 [00:12<00:17, 454.67it/s]
# Computing likelihoods:  37%|███▋      | 4642/12500 [00:12<00:17, 459.62it/s]
# Computing likelihoods:  38%|███▊      | 4689/12500 [00:12<00:17, 451.02it/s]
# Computing likelihoods:  38%|███▊      | 4735/12500 [00:13<00:17, 447.90it/s]
# Computing likelihoods:  38%|███▊      | 4781/12500 [00:13<00:17, 449.26it/s]
# Computing likelihoods:  39%|███▊      | 4826/12500 [00:13<00:17, 444.05it/s]
# Computing likelihoods:  39%|███▉      | 4872/12500 [00:13<00:17, 446.04it/s]
# Computing likelihoods:  39%|███▉      | 4917/12500 [00:13<00:18, 411.92it/s]
# Computing likelihoods:  40%|███▉      | 4959/12500 [00:13<00:18, 400.95it/s]
# Computing likelihoods:  40%|████      | 5000/12500 [00:13<00:19, 394.09it/s]
# Computing likelihoods:  40%|████      | 5040/12500 [00:13<00:20, 370.15it/s]
# Computing likelihoods:  41%|████      | 5083/12500 [00:13<00:19, 385.87it/s]
# Computing likelihoods:  41%|████      | 5129/12500 [00:14<00:18, 404.10it/s]
# Computing likelihoods:  41%|████▏     | 5171/12500 [00:14<00:18, 390.33it/s]
# Computing likelihoods:  42%|████▏     | 5211/12500 [00:14<00:19, 375.15it/s]
# Computing likelihoods:  42%|████▏     | 5250/12500 [00:14<00:19, 363.45it/s]
# Computing likelihoods:  42%|████▏     | 5287/12500 [00:14<00:19, 365.37it/s]
# Computing likelihoods:  43%|████▎     | 5325/12500 [00:14<00:19, 369.38it/s]
# Computing likelihoods:  43%|████▎     | 5378/12500 [00:14<00:17, 403.73it/s]
# Computing likelihoods:  43%|████▎     | 5429/12500 [00:14<00:16, 428.35it/s]
# Computing likelihoods:  44%|████▍     | 5476/12500 [00:14<00:15, 439.51it/s]
# Computing likelihoods:  44%|████▍     | 5531/12500 [00:14<00:15, 464.50it/s]
# Computing likelihoods:  45%|████▍     | 5579/12500 [00:15<00:14, 462.48it/s]
# Computing likelihoods:  45%|████▌     | 5626/12500 [00:15<00:15, 439.42it/s]
# Computing likelihoods:  45%|████▌     | 5671/12500 [00:15<00:15, 442.50it/s]
# Computing likelihoods:  46%|████▌     | 5716/12500 [00:15<00:15, 432.23it/s]
# Computing likelihoods:  46%|████▌     | 5760/12500 [00:15<00:16, 399.93it/s]
# Computing likelihoods:  46%|████▋     | 5801/12500 [00:15<00:17, 386.21it/s]
# Computing likelihoods:  47%|████▋     | 5841/12500 [00:15<00:17, 371.65it/s]
# Computing likelihoods:  47%|████▋     | 5885/12500 [00:15<00:16, 389.47it/s]
# Computing likelihoods:  47%|████▋     | 5931/12500 [00:15<00:16, 405.41it/s]
# Computing likelihoods:  48%|████▊     | 5976/12500 [00:16<00:15, 415.62it/s]
# Computing likelihoods:  48%|████▊     | 6022/12500 [00:16<00:15, 425.61it/s]
# Computing likelihoods:  49%|████▊     | 6065/12500 [00:16<00:15, 425.34it/s]
# Computing likelihoods:  49%|████▉     | 6119/12500 [00:16<00:14, 453.42it/s]
# Computing likelihoods:  49%|████▉     | 6166/12500 [00:16<00:14, 426.82it/s]
# Computing likelihoods:  50%|████▉     | 6211/12500 [00:16<00:14, 431.37it/s]
# Computing likelihoods:  50%|█████     | 6255/12500 [00:16<00:15, 410.50it/s]
# Computing likelihoods:  50%|█████     | 6297/12500 [00:16<00:15, 398.20it/s]
# Computing likelihoods:  51%|█████     | 6347/12500 [00:16<00:14, 424.08it/s]
# Computing likelihoods:  51%|█████     | 6393/12500 [00:17<00:14, 431.73it/s]
# Computing likelihoods:  52%|█████▏    | 6440/12500 [00:17<00:13, 442.16it/s]
# Computing likelihoods:  52%|█████▏    | 6485/12500 [00:17<00:13, 438.98it/s]
# Computing likelihoods:  52%|█████▏    | 6536/12500 [00:17<00:13, 457.57it/s]
# Computing likelihoods:  53%|█████▎    | 6583/12500 [00:17<00:13, 427.35it/s]
# Computing likelihoods:  53%|█████▎    | 6627/12500 [00:17<00:14, 416.89it/s]
# Computing likelihoods:  53%|█████▎    | 6670/12500 [00:17<00:13, 420.28it/s]
# Computing likelihoods:  54%|█████▎    | 6714/12500 [00:17<00:13, 424.56it/s]
# Computing likelihoods:  54%|█████▍    | 6761/12500 [00:17<00:13, 436.07it/s]
# Computing likelihoods:  54%|█████▍    | 6805/12500 [00:18<00:13, 428.12it/s]
# Computing likelihoods:  55%|█████▍    | 6854/12500 [00:18<00:12, 443.54it/s]
# Computing likelihoods:  55%|█████▌    | 6901/12500 [00:18<00:12, 450.63it/s]
# Computing likelihoods:  56%|█████▌    | 6947/12500 [00:18<00:12, 447.47it/s]
# Computing likelihoods:  56%|█████▌    | 6992/12500 [00:18<00:12, 429.34it/s]
# Computing likelihoods:  56%|█████▋    | 7039/12500 [00:18<00:12, 437.94it/s]
# Computing likelihoods:  57%|█████▋    | 7085/12500 [00:18<00:12, 441.94it/s]
# Computing likelihoods:  57%|█████▋    | 7132/12500 [00:18<00:11, 449.10it/s]
# Computing likelihoods:  57%|█████▋    | 7180/12500 [00:18<00:11, 455.69it/s]
# Computing likelihoods:  58%|█████▊    | 7226/12500 [00:18<00:11, 451.74it/s]
# Computing likelihoods:  58%|█████▊    | 7275/12500 [00:19<00:11, 460.11it/s]
# Computing likelihoods:  59%|█████▊    | 7327/12500 [00:19<00:10, 473.36it/s]
# Computing likelihoods:  59%|█████▉    | 7375/12500 [00:19<00:10, 473.81it/s]
# Computing likelihoods:  59%|█████▉    | 7423/12500 [00:19<00:12, 408.32it/s]
# Computing likelihoods:  60%|█████▉    | 7466/12500 [00:19<00:12, 391.03it/s]
# Computing likelihoods:  60%|██████    | 7507/12500 [00:19<00:13, 383.07it/s]
# Computing likelihoods:  60%|██████    | 7551/12500 [00:19<00:12, 397.38it/s]
# Computing likelihoods:  61%|██████    | 7595/12500 [00:19<00:11, 408.84it/s]
# Computing likelihoods:  61%|██████    | 7639/12500 [00:19<00:11, 417.22it/s]
# Computing likelihoods:  62%|██████▏   | 7694/12500 [00:20<00:10, 447.72it/s]
# Computing likelihoods:  62%|██████▏   | 7740/12500 [00:20<00:11, 427.26it/s]
# Computing likelihoods:  62%|██████▏   | 7784/12500 [00:20<00:11, 399.69it/s]
# Computing likelihoods:  63%|██████▎   | 7827/12500 [00:20<00:11, 406.79it/s]
# Computing likelihoods:  63%|██████▎   | 7869/12500 [00:20<00:11, 393.72it/s]
# Computing likelihoods:  63%|██████▎   | 7918/12500 [00:20<00:10, 417.34it/s]
# Computing likelihoods:  64%|██████▎   | 7961/12500 [00:20<00:11, 405.90it/s]
# Computing likelihoods:  64%|██████▍   | 8003/12500 [00:20<00:11, 383.31it/s]
# Computing likelihoods:  64%|██████▍   | 8053/12500 [00:20<00:10, 409.48it/s]
# Computing likelihoods:  65%|██████▍   | 8095/12500 [00:21<00:10, 411.71it/s]
# Computing likelihoods:  65%|██████▌   | 8137/12500 [00:21<00:10, 399.42it/s]
# Computing likelihoods:  65%|██████▌   | 8178/12500 [00:21<00:11, 380.76it/s]
# Computing likelihoods:  66%|██████▌   | 8225/12500 [00:21<00:10, 403.74it/s]
# Computing likelihoods:  66%|██████▌   | 8277/12500 [00:21<00:09, 431.07it/s]
# Computing likelihoods:  67%|██████▋   | 8331/12500 [00:21<00:09, 456.52it/s]
# Computing likelihoods:  67%|██████▋   | 8378/12500 [00:21<00:10, 406.23it/s]
# Computing likelihoods:  67%|██████▋   | 8421/12500 [00:21<00:10, 385.30it/s]
# Computing likelihoods:  68%|██████▊   | 8466/12500 [00:21<00:10, 401.94it/s]
# Computing likelihoods:  68%|██████▊   | 8513/12500 [00:22<00:09, 418.38it/s]
# Computing likelihoods:  69%|██████▊   | 8569/12500 [00:22<00:08, 452.43it/s]
# Computing likelihoods:  69%|██████▉   | 8621/12500 [00:22<00:08, 469.05it/s]
# Computing likelihoods:  69%|██████▉   | 8672/12500 [00:22<00:08, 477.12it/s]
# Computing likelihoods:  70%|██████▉   | 8723/12500 [00:22<00:07, 482.79it/s]
# Computing likelihoods:  70%|███████   | 8772/12500 [00:22<00:08, 462.84it/s]
# Computing likelihoods:  71%|███████   | 8829/12500 [00:22<00:07, 487.84it/s]
# Computing likelihoods:  71%|███████   | 8882/12500 [00:22<00:07, 496.15it/s]
# Computing likelihoods:  71%|███████▏  | 8933/12500 [00:22<00:07, 484.98it/s]
# Computing likelihoods:  72%|███████▏  | 8982/12500 [00:23<00:07, 441.60it/s]
# Computing likelihoods:  72%|███████▏  | 9028/12500 [00:23<00:09, 383.39it/s]
# Computing likelihoods:  73%|███████▎  | 9079/12500 [00:23<00:08, 413.71it/s]
# Computing likelihoods:  73%|███████▎  | 9133/12500 [00:23<00:07, 442.14it/s]
# Computing likelihoods:  73%|███████▎  | 9180/12500 [00:23<00:07, 444.47it/s]
# Computing likelihoods:  74%|███████▍  | 9229/12500 [00:23<00:07, 454.54it/s]
# Computing likelihoods:  74%|███████▍  | 9276/12500 [00:23<00:07, 454.43it/s]
# Computing likelihoods:  75%|███████▍  | 9323/12500 [00:23<00:07, 452.11it/s]
# Computing likelihoods:  75%|███████▌  | 9375/12500 [00:23<00:06, 470.24it/s]
# Computing likelihoods:  75%|███████▌  | 9427/12500 [00:23<00:06, 483.96it/s]
# Computing likelihoods:  76%|███████▌  | 9479/12500 [00:24<00:06, 492.33it/s]
# Computing likelihoods:  76%|███████▋  | 9535/12500 [00:24<00:05, 509.08it/s]
# Computing likelihoods:  77%|███████▋  | 9587/12500 [00:24<00:05, 504.69it/s]
# Computing likelihoods:  77%|███████▋  | 9638/12500 [00:24<00:05, 490.26it/s]
# Computing likelihoods:  78%|███████▊  | 9688/12500 [00:24<00:05, 473.80it/s]
# Computing likelihoods:  78%|███████▊  | 9740/12500 [00:24<00:05, 484.81it/s]
# Computing likelihoods:  78%|███████▊  | 9789/12500 [00:24<00:05, 459.30it/s]
# Computing likelihoods:  79%|███████▊  | 9838/12500 [00:24<00:05, 467.38it/s]
# Computing likelihoods:  79%|███████▉  | 9889/12500 [00:24<00:05, 477.56it/s]
# Computing likelihoods:  80%|███████▉  | 9938/12500 [00:25<00:05, 465.64it/s]
# Computing likelihoods:  80%|███████▉  | 9986/12500 [00:25<00:05, 468.99it/s]
# Computing likelihoods:  80%|████████  | 10034/12500 [00:25<00:05, 460.24it/s]
# Computing likelihoods:  81%|████████  | 10081/12500 [00:25<00:05, 448.58it/s]
# Computing likelihoods:  81%|████████  | 10127/12500 [00:25<00:05, 435.44it/s]
# Computing likelihoods:  81%|████████▏ | 10171/12500 [00:25<00:05, 434.09it/s]
# Computing likelihoods:  82%|████████▏ | 10217/12500 [00:25<00:05, 440.97it/s]
# Computing likelihoods:  82%|████████▏ | 10266/12500 [00:25<00:04, 451.91it/s]
# Computing likelihoods:  83%|████████▎ | 10315/12500 [00:25<00:04, 461.57it/s]
# Computing likelihoods:  83%|████████▎ | 10362/12500 [00:26<00:04, 459.68it/s]
# Computing likelihoods:  83%|████████▎ | 10409/12500 [00:26<00:04, 449.16it/s]
# Computing likelihoods:  84%|████████▎ | 10455/12500 [00:26<00:04, 442.26it/s]
# Computing likelihoods:  84%|████████▍ | 10503/12500 [00:26<00:04, 451.63it/s]
# Computing likelihoods:  84%|████████▍ | 10554/12500 [00:26<00:04, 467.20it/s]
# Computing likelihoods:  85%|████████▍ | 10608/12500 [00:26<00:03, 484.20it/s]
# Computing likelihoods:  85%|████████▌ | 10658/12500 [00:26<00:03, 484.40it/s]
# Computing likelihoods:  86%|████████▌ | 10709/12500 [00:26<00:03, 489.76it/s]
# Computing likelihoods:  86%|████████▌ | 10759/12500 [00:26<00:03, 460.58it/s]
# Computing likelihoods:  86%|████████▋ | 10806/12500 [00:26<00:03, 453.33it/s]
# Computing likelihoods:  87%|████████▋ | 10852/12500 [00:27<00:03, 453.23it/s]
# Computing likelihoods:  87%|████████▋ | 10899/12500 [00:27<00:03, 458.12it/s]
# Computing likelihoods:  88%|████████▊ | 10951/12500 [00:27<00:03, 470.79it/s]
# Computing likelihoods:  88%|████████▊ | 11004/12500 [00:27<00:03, 484.24it/s]
# Computing likelihoods:  88%|████████▊ | 11053/12500 [00:27<00:02, 485.86it/s]
# Computing likelihoods:  89%|████████▉ | 11105/12500 [00:27<00:02, 491.37it/s]
# Computing likelihoods:  89%|████████▉ | 11155/12500 [00:27<00:02, 484.91it/s]
# Computing likelihoods:  90%|████████▉ | 11209/12500 [00:27<00:02, 499.02it/s]
# Computing likelihoods:  90%|█████████ | 11266/12500 [00:27<00:02, 517.97it/s]
# Computing likelihoods:  91%|█████████ | 11319/12500 [00:27<00:02, 502.60it/s]
# Computing likelihoods:  91%|█████████ | 11370/12500 [00:28<00:02, 497.38it/s]
# Computing likelihoods:  91%|█████████▏| 11420/12500 [00:28<00:02, 483.98it/s]
# Computing likelihoods:  92%|█████████▏| 11469/12500 [00:28<00:02, 474.26it/s]
# Computing likelihoods:  92%|█████████▏| 11526/12500 [00:28<00:01, 497.57it/s]
# Computing likelihoods:  93%|█████████▎| 11577/12500 [00:28<00:01, 499.69it/s]
# Computing likelihoods:  93%|█████████▎| 11628/12500 [00:28<00:01, 490.72it/s]
# Computing likelihoods:  93%|█████████▎| 11678/12500 [00:28<00:01, 472.57it/s]
# Computing likelihoods:  94%|█████████▍| 11728/12500 [00:28<00:01, 478.13it/s]
# Computing likelihoods:  94%|█████████▍| 11777/12500 [00:28<00:01, 477.89it/s]
# Computing likelihoods:  95%|█████████▍| 11827/12500 [00:29<00:01, 481.05it/s]
# Computing likelihoods:  95%|█████████▌| 11876/12500 [00:29<00:01, 469.71it/s]
# Computing likelihoods:  95%|█████████▌| 11930/12500 [00:29<00:01, 488.11it/s]
# Computing likelihoods:  96%|█████████▌| 11980/12500 [00:29<00:01, 479.02it/s]
# Computing likelihoods:  96%|█████████▋| 12032/12500 [00:29<00:00, 488.17it/s]
# Computing likelihoods:  97%|█████████▋| 12082/12500 [00:29<00:00, 473.35it/s]
# Computing likelihoods:  97%|█████████▋| 12130/12500 [00:29<00:00, 471.76it/s]
# Computing likelihoods:  97%|█████████▋| 12180/12500 [00:29<00:00, 477.44it/s]
# Computing likelihoods:  98%|█████████▊| 12228/12500 [00:29<00:00, 472.93it/s]
# Computing likelihoods:  98%|█████████▊| 12276/12500 [00:29<00:00, 471.29it/s]
# Computing likelihoods:  99%|█████████▊| 12324/12500 [00:30<00:00, 464.46it/s]
# Computing likelihoods:  99%|█████████▉| 12376/12500 [00:30<00:00, 477.12it/s]
# Computing likelihoods:  99%|█████████▉| 12424/12500 [00:30<00:00, 474.35it/s]
# Computing likelihoods: 100%|█████████▉| 12472/12500 [00:30<00:00, 462.37it/s]
# Computing likelihoods: 12520it [00:30, 466.20it/s]
# Computing likelihoods: 12550it [00:47, 466.20it/s]

# %%
fit_result = np.median(samples, axis=0)
l, r = np.percentile(samples, 100 * stats.norm.cdf([-1, 1]), axis=0)
sigma = (r - l)/2
q = np.round(fit_result, 2), np.round(sigma, 2)
D = fit_result[0] * (units.cm**2 / units.s)
w0 = fit_result[1]
diffusion_const = D/(units.cm**2 / units.s)
print(f'Diffusion constant = {D/(units.cm**2 / units.s):.2f} cm^2/s')
width_hist_cut.plot(log_scale=True, cblabel='events')
plt.xlabel('drift time ($\mu$s)')
plt.ylabel('S2 width range 50% area (ns)')
ts = np.linspace(0, 800, 100) * units.us
plt.plot(ts / units.us, diffusion_model(ts, D, drift_velocity, w0),
         linestyle=':', linewidth=2, c='r',label='model')
plt.legend()
plt.savefig('diffusion_constant.png')
# Out:
# Diffusion constant = 33.26 cm^2/s

# %%
import corner
corner.corner(samples, show_titles=True, labels=['D', 'w0', 'wsig'])
#plt.savefig('D_corner_%s' % ds['desc'])
# Out:
# WARNING:root:Too few points to create valid contours
