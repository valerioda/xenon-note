# %%
import socket
import strax
import straxen
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import datetime
import pandas as pd

from multihist import Hist1d, Histdd
import time
import itertools
import os

from scipy import stats
from straxen import units
from scipy.optimize import curve_fit

import peaks_utility as psu
import drift_diffusion_utility as ddu
import s2widthcut_utility as wcu
import math
from datetime import datetime, timedelta
import cutax
from straxen.get_corrections import get_correction_from_cmt
from cutax.cuts import *

# %load_ext autoreload
# %autoreload 2
#import importlib
#importlib.reload(cutax)

# %%
straxen.print_versions()
# Out:
#     module version                                               path   git
# 0   python  3.8.13  /opt/XENONnT/anaconda/envs/XENONnT_2022.06.3/b...  None
# 1    strax   1.2.3  /opt/XENONnT/anaconda/envs/XENONnT_2022.06.3/l...  None
# 2  straxen   1.7.1  /opt/XENONnT/anaconda/envs/XENONnT_2022.06.3/l...  None
# 3    cutax  1.12.0  /dali/lgrandi/xenonnt/software/cutax/v1.12.0/c...  None

# %%
#st = cutax.xenonnt_v5(cuts_for=['science_run_0.krypton_selections', 'commissioning.commissioning_cuts'])
st = cutax.contexts.xenonnt_v8(cut_list=[cutax.cut_lists.basic.BasicCuts,cutax.cut_lists.s2width_test.S2Width])
#st = cutax.xenonnt_online()
#st.register(FiducialVolumeCylinder)
FiducialVolume = st.get_single_plugin('030000', 'cut_fiducial_volume')
NearWires = st.get_single_plugin('030000', 'cut_near_wires')

# %%
evRn = pd.read_hdf('/dali/lgrandi/dandrea/data/20220603_sr0_rn220_v8.h5', key='df')

# %%
evAr = pd.read_hdf('/dali/lgrandi/dandrea/data/20220603_sr0_ar37_v8.h5', key='df')

# %%
evRn = evRn[wcu.all_cuts(evRn,wimps=1)]
evAr = evAr[wcu.all_cuts(evAr,wimps=1)]

# %%
dsets = st.select_runs(include_tags='*sr0*',run_mode='tpc_ambe',available='event_info')
# Out:
# Checking data availability:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
ambe_runs = np.array(dsets['name'])

# %%
len(ambe_runs)
# Out:
# 191

# %%
evAB = wcu.merge_runs_cutax(st,ambe_runs)
# Out:
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# Reading runs from 020362 to 021285
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:29: RuntimeWarning: invalid value encountered in power
#   ret = p0 / (x ** p1) + p2 + p3 * x ** p4
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:35: RuntimeWarning: invalid value encountered in power
#   ret =  p0 * np.power(x, p1) * np.exp(-p2 * x) + p3 + p4 * x
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/naive_bayes_classifier.py:39: RuntimeWarning: invalid value encountered in power
#   ret = p0 * np.power(x, p1) * np.exp(-p2 * (x - p3))
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# n. 4 run 021251 elapsed time: 9.48 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:265: RuntimeWarning: invalid value encountered in multiply
#   return np.clip(y_lim, 1, np.inf) * ry
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:29: RuntimeWarning: invalid value encountered in power
#   ret = p0 / (x ** p1) + p2 + p3 * x ** p4
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:35: RuntimeWarning: invalid value encountered in power
#   ret =  p0 * np.power(x, p1) * np.exp(-p2 * x) + p3 + p4 * x
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/naive_bayes_classifier.py:39: RuntimeWarning: invalid value encountered in power
#   ret = p0 * np.power(x, p1) * np.exp(-p2 * (x - p3))
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# n. 9 run 021233 elapsed time: 21.22 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:29: RuntimeWarning: invalid value encountered in power
#   ret = p0 / (x ** p1) + p2 + p3 * x ** p4
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:35: RuntimeWarning: invalid value encountered in power
#   ret =  p0 * np.power(x, p1) * np.exp(-p2 * x) + p3 + p4 * x
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/naive_bayes_classifier.py:39: RuntimeWarning: invalid value encountered in power
#   ret = p0 * np.power(x, p1) * np.exp(-p2 * (x - p3))
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# n. 14 run 021215 elapsed time: 33.58 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# n. 19 run 021200 elapsed time: 45.84 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# n. 24 run 021185 elapsed time: 58.37 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# n. 29 run 021170 elapsed time: 75.95 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:29: RuntimeWarning: invalid value encountered in power
#   ret = p0 / (x ** p1) + p2 + p3 * x ** p4
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:35: RuntimeWarning: invalid value encountered in power
#   ret =  p0 * np.power(x, p1) * np.exp(-p2 * x) + p3 + p4 * x
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/naive_bayes_classifier.py:39: RuntimeWarning: invalid value encountered in power
#   ret = p0 * np.power(x, p1) * np.exp(-p2 * (x - p3))
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:265: RuntimeWarning: invalid value encountered in multiply
#   return np.clip(y_lim, 1, np.inf) * ry
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# n. 34 run 021155 elapsed time: 91.15 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:29: RuntimeWarning: invalid value encountered in power
#   ret = p0 / (x ** p1) + p2 + p3 * x ** p4
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:35: RuntimeWarning: invalid value encountered in power
#   ret =  p0 * np.power(x, p1) * np.exp(-p2 * x) + p3 + p4 * x
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/naive_bayes_classifier.py:39: RuntimeWarning: invalid value encountered in power
#   ret = p0 * np.power(x, p1) * np.exp(-p2 * (x - p3))
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# n. 39 run 021140 elapsed time: 106.04 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:102: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:102: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:106: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:106: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# n. 44 run 021125 elapsed time: 121.58 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# ...
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# n. 179 run 020795 elapsed time: 577.64 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# n. 184 run 020785 elapsed time: 595.08 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:245: RuntimeWarning: divide by zero encountered in true_divide
#   return flat + (amp / np.clip(s2_area_top, 0, cutoff)) ** power
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# n. 189 run 020362 elapsed time: 613.78 s
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in sqrt
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:155: RuntimeWarning: invalid value encountered in power
#   return a1**2 * x**(1/2) + b1 * x + c1 * x**(3/2) + d1
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in sqrt
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_pattern.py:159: RuntimeWarning: invalid value encountered in power
#   return a3**2 * x**(1/2) + b3 * x + c3 * x**(3/2) + d3
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:29: RuntimeWarning: invalid value encountered in power
#   ret = p0 / (x ** p1) + p2 + p3 * x ** p4
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s1_width.py:35: RuntimeWarning: invalid value encountered in power
#   ret =  p0 * np.power(x, p1) * np.exp(-p2 * x) + p3 + p4 * x
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/naive_bayes_classifier.py:39: RuntimeWarning: invalid value encountered in power
#   ret = p0 * np.power(x, p1) * np.exp(-p2 * (x - p3))
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:150: RuntimeWarning: invalid value encountered in sqrt
#   return self.sigma_to_r50p * np.sqrt(2 * self.diffusion_constant *
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:167: RuntimeWarning: divide by zero encountered in true_divide
#   return ( s2_width_50p**2 - self.config['s2_secondary_sc_width']**2 ) / self.s2_width_model(drift_time)**2
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:252: RuntimeWarning: divide by zero encountered in true_divide
#   k0 = self.config['s2_width_wire_model_slope'] * rx / ry  # slope in rescaled space
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:255: RuntimeWarning: divide by zero encountered in true_divide
#   yc = self.config['s2_width_wire_model_intercept'] / ry  # interception of the center
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:257: RuntimeWarning: invalid value encountered in subtract
#   y_linear = y0 + yc - np.abs(x_tmp) * k0
# /dali/lgrandi/xenonnt/software/cutax/v1.12.0/cutax/cuts/s2_width.py:265: RuntimeWarning: invalid value encountered in multiply
#   return np.clip(y_lim, 1, np.inf) * ry

# %%
evAB.to_hdf('/dali/lgrandi/dandrea/data/20220603_sr0_ambe_v8.h5', key='df', mode='w')
#evAB = pd.read_hdf('/dali/lgrandi/dandrea/data/20220603_sr0_ambe_v8.h5', key='df')

# %%
evAB = evAB[wcu.all_cuts(evAB,wimps=1)]

# %%
ev_sim = np.load('/dali/lgrandi/shenyangshi/s2_width_wfsim_0615.npy', allow_pickle=True)
#ev_sim = np.load('/dali/lgrandi/shenyangshi/bdt_acceptance_0620.npy', allow_pickle=True).item()
#ev_sim = ev_sim['wfsim']
ev_sim = ev_sim[FiducialVolume.cut_by(ev_sim)]

# %%
vd = get_correction_from_cmt('024075',('electron_drift_velocity', 'ONLINE', True))
gd = get_correction_from_cmt('024075',('electron_drift_time_gate', 'ONLINE', True))
dc = get_correction_from_cmt('024075',('electron_diffusion_cte', 'ONLINE', True))
par = (dc,vd,gd)
print(par)
# Out:
# (4.566e-08, 6.77e-05, 2700.0)

# %% [markdown]
# # WFsim Acceptance

# %%
# FAR FROM WIRES 1-99%
cut_far = (( 0.75785949 , 3.18263529 , 1.26349891 ),
          ( 4.74467848 , 1.34106577 , 1.99650474 , 1.02559667 ))
# NEAR WIRES 5-99%
cut_near = (( 0.7742574 , 2.92714807 , 1.22338626 ),
           ( 4.74467848 , 1.34106577 , 1.99650474 , 1.02559667 ))

# %%
mask_near_wires = NearWires.cut_by(ev_sim)
# get cut mask for WFsim near wires for WIMPs 1-99%
cut_mask_sim_near = wcu.S2WidthCut(ev_sim[mask_near_wires], title='WFsim near wires',
                                   mod_par=par, bins=400,
                                   wrange=(0,6), arange = (2.2,6.5), plot = 0,
                                   perc_plot=0,
                                   ext_par=cut_near, near_wires=1, wire_model=1 )
cut_mask_sim_near = cut_mask_sim_near[1]
# get cut mask for WFsim far from wires for WIMPs 5-99%
cut_mask_sim_far = wcu.S2WidthCut(ev_sim[~mask_near_wires], title='WFsim far wires',
                                  mod_par=par, bins=400,
                                  wrange=(0,6), arange = (2.2,6.5), plot = 0,
                                  perc_plot=0,
                                  ext_par=cut_far)
cut_mask_sim_far = cut_mask_sim_far[1]
#cut_mask_sim_near[~mask_near_wires] = True
#cut_mask_sim_far[mask_near_wires] = True 
#cut_mask_sim = cut_mask_sim_near & cut_mask_sim_far

# %%
evFar = ev_sim[~mask_near_wires]
wcu.plot_r2z_xy(evFar, 'WFsim - Far Wires')
accFarSim = wcu.get_acceptance(evFar, cut_mask_sim_far,
                               title='WFsim - Far Wires', alim=(0.7,1))
# Out:
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),

# %%
evNear = ev_sim[mask_near_wires]
wcu.plot_r2z_xy(evNear, 'WFsim - Near Wires')
accNearSim = wcu.get_acceptance(evNear, cut_mask_sim_near,
                               title='WFsim - Near Wires', alim=(0.7,1))
# Out:
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),

# %% [markdown]
# # Data Acceptance

# %%
ev = evRn
evFar = ev[ev['cut_near_wires']==0]
#wcu.plot_r2z_xy(evFar, 'AmBe data - Far Wires')
accFarRn = wcu.get_acceptance(evFar, evFar['cut_s2_width_wire_modeled_wimps'],
                              title='Rn220 data - Far Wires', alim=(0.7,1))

# %%
evNear = ev[ev['cut_near_wires']]
accNearRn = wcu.get_acceptance(evNear, evNear['cut_s2_width_wire_modeled_wimps'],
                              title='Rn220 data - Near Wires', alim=(0.7,1))

# %%
ev = evAr
evFar = ev[ev['cut_near_wires']==0]
accFarAr = wcu.get_acceptance(evFar, evFar['cut_s2_width_wire_modeled_wimps'],
                              title='Ar37 data - Far Wires', alim=(0.7,1))
# Out:
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),

# %%
evNear = ev[ev['cut_near_wires']]
accNearAr = wcu.get_acceptance(evNear, evNear['cut_s2_width_wire_modeled_wimps'],
                              title='Ar37 data - Near Wires', alim=(0.7,1))
# Out:
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),

# %%
ev = evAB
evFar = ev[ev['cut_near_wires']==0]
wcu.plot_r2z_xy(evFar, 'AmBe data - Far Wires')
accFarAB = wcu.get_acceptance(evFar, evFar['cut_s2_width_wire_modeled_wimps'],
                              title='AmBe data - Far Wires', alim=(0.7,1))
# Out:
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),

# %%
evNear = ev[ev['cut_near_wires']]
accNearAB = wcu.get_acceptance(evNear, evNear['cut_s2_width_wire_modeled_wimps'],
                              title='AmBe data - Near Wires', alim=(0.7,1))
# Out:
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:752: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),

# %%
wcu.plot_acceptance(accFarRn, accFarSim, alim=(0.7,1),title='FarWires',
                    info='Rn220',save=0)

# %%
wcu.plot_acceptance(accNearRn, accNearSim, alim=(0.85,1),title='NearWires',
                    info='Rn220',save=0)

# %%
acc_f = wcu.apply_cut_on_data(ev, par, cut_far, width_type = '50p', far_wires = 1, wrange = (0,1.5),
                      acc_calc = 1, alim=(0.8,1),plot=1)#, info = 'Rn220_Ar37_far_wires')
# Out:
# Lower and higher boundary provided externally
# param_parabola_low: [0.00487747 0.09634788 0.19632396]
# param_parabola_high: [ 0.12086412 -1.22950531  4.37592357]
# Cut: total 7449332, survived 7226685 -> 97.01%
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:593: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),

# %%
acc_n = wcu.apply_cut_on_data(ev, par, cut_near, width_type = '50p', near_wires = 1, wrange = (0,6),
                      acc_calc = 1, alim=(0.8,1), info = 'Rn220_Ar37_near_wires',wire_model=1,plot=1)
# Out:
# /home/valerioda/xenon-notes/fast_response_analysis/s2widthcut_utility.py:594: RuntimeWarning: invalid value encountered in long_scalars
#   avg = k / n
# /home/valerioda/.local/lib/python3.8/site-packages/multihist-0.6.5-py3.8.egg/multihist.py:106: RuntimeWarning: invalid value encountered in true_divide
#   getattr(self.histogram, opname)(other),

# %%
# FAR WIRES Rn-220
wcu.apply_cut_on_data(evRn, par, cut_far, width_type = '50p', far_wires = 1, wrange = (0,6),
                      acc_calc = 1,plot=1, alim=(0.8,1), info = 'Rn220_farwire')
# Out:
# Lower and higher boundary provided externally
# param_parabola_low: [0.00487747 0.09634788 0.19632396]
# param_parabola_high: [ 0.12086552 -1.22952077  4.37596573]
# Cut: total 439848, survived 340652 -> 77.45%

# %%
# NEAR WIRES Rn-220
wcu.apply_cut_on_data(evRn, par, cut_far, width_type = '50p', near_wires = 1, wrange = (0,6),
                      acc_calc = 1, alim=(0.8,1), info = 'Rn220_nearwire_lower',plot=1)
# Out:
# Lower and higher boundary provided externally
# param_parabola_low: [0.00487747 0.09634788 0.19632396]
# param_parabola_high: [ 0.12086552 -1.22952077  4.37596573]
# Cut: total 89159, survived 88789 -> 99.59%

# %%
# NEAR WIRES WIRE MODEL Rn-220
wcu.apply_cut_on_data(evRn, par, cut_near, width_type = '50p', near_wires = 1, wrange = (0,6),plot=1,
                      acc_calc = 1,alim=(0.8,1), info = 'Rn220_nearwire_lower_model',wire_model=1)
# Out:
# Lower and higher boundary provided externally
# param_parabola_low: [ 0.03578608 -0.24364693  1.12358253]
# param_parabola_high: [ 0.12086552 -1.22952077  4.37596573]
# Cut: total 89159, survived 88732 -> 99.52%
# Cut wire modeled: total 89159, survived 76841 -> 86.18%
